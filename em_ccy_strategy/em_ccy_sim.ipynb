# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My\ Drive/Colab\ Notebooks/em_ccy_strategy
# Out:
# /content/drive/My Drive/Colab Notebooks/em_ccy_strategy

# %%
# !python -m simulation.em_ccy_sim_fc
# Out:
# [INFO] - 2020-07-24 13:54:27,118 - em_ccy_sim_fc - __init__ - EMCcySim initializing...
# [INFO] - 2020-07-24 13:54:28,338 - utils - _init_num_threads - NumExpr defaulting to 2 threads.
# [INFO] - 2020-07-24 13:54:28,372 - em_ccy_sim_fc - _get_price - Getting Data From Master Data...
# [INFO] - 2020-07-24 13:54:28,431 - em_ccy_sim_fc - __init__ - EMCcySim initialized.
# [INFO] - 2020-07-24 13:54:28,431 - em_ccy_sim_fc - simulate - Simulation Starting...
# [INFO] - 2020-07-24 13:54:28,438 - em_ccy_sim_fc - _calc_return - Calculating Normal Return...
# [INFO] - 2020-07-24 13:54:42,171 - em_ccy_sim_fc - simulate - Selecting EM Currency Tickers usgin Rate
# [INFO] - 2020-07-24 13:54:43,527 - em_ccy_sim_fc - simulate - Building Position...
# [INFO] - 2020-07-24 13:54:43,877 - em_ccy_sim_fc - _calc_return_inc_swap - Calculating Log Return including Swap Cost...
# [INFO] - 2020-07-24 13:54:44,357 - em_ccy_sim_fc - simulate - Calculating Perofrmance...
# ...

# %%
pwd
# Out:
# '/content'
