# %% [markdown]
# <a href="https://colab.research.google.com/github/noryxjr1/tateishi/blob/master/ml_fc_sim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My\ Drive/Colab\ Notebooks/em_ccy_strategy
# Out:
# /content/drive/My Drive/Colab Notebooks/em_ccy_strategy

# %%
# !python -m simulation.ml_fc_sim
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Epoch 21/150
# 2/2 - 0s - loss: 3.0761 - acc: 0.5440 - val_loss: 5.2872 - val_acc: 0.4062
# Epoch 22/150
# 2/2 - 0s - loss: 3.8028 - acc: 0.5360 - val_loss: 5.2690 - val_acc: 0.4062
# Epoch 23/150
# 2/2 - 0s - loss: 2.9344 - acc: 0.5520 - val_loss: 5.2516 - val_acc: 0.4062
# Epoch 24/150
# 2/2 - 0s - loss: 4.2690 - acc: 0.5040 - val_loss: 5.2382 - val_acc: 0.4062
# Epoch 25/150
# 2/2 - 0s - loss: 4.5827 - acc: 0.4880 - val_loss: 5.2359 - val_acc: 0.4062
# Epoch 26/150
# 2/2 - 0s - loss: 3.2075 - acc: 0.5760 - val_loss: 5.2296 - val_acc: 0.4062
# Epoch 27/150
# 2/2 - 0s - loss: 3.4396 - acc: 0.5520 - val_loss: 4.8390 - val_acc: 0.4062
# Epoch 28/150
# 2/2 - 0s - loss: 3.9547 - acc: 0.5200 - val_loss: 4.4481 - val_acc: 0.4062
# Epoch 29/150
# 2/2 - 0s - loss: 4.6211 - acc: 0.4960 - val_loss: 4.3991 - val_acc: 0.4062
# Epoch 30/150
# 2/2 - 0s - loss: 3.6826 - acc: 0.5760 - val_loss: 4.3708 - val_acc: 0.4062
# Epoch 31/150
# ...
